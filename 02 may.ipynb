# %%
# Q1
'''Anomaly detection identifies suspicious activity that falls outside of your established normal patterns of behavior.
   A solution protects your system in real-time from instances that could result in significant financial losses, data
   breaches, and other harmful events.
   Anomaly detection is the identification of rare events, items, or observations which are suspicious because they 
   differ significantly from standard behaviors or patterns. Anomalies in data are also called standard deviations,
   outliers, noise, novelties, and exceptions.
'''
# Out:
# 'Anomaly detection identifies suspicious activity that falls outside of your established normal patterns of behavior.\n   A solution protects your system in real-time from instances that could result in significant financial losses, data\n   breaches, and other harmful events.\n   Anomaly detection is the identification of rare events, items, or observations which are suspicious because they \n   differ significantly from standard behaviors or patterns. Anomalies in data are also called standard deviations,\n   outliers, noise, novelties, and exceptions.\n'

# %%
# Q2
'''Challenges in anomaly detection include appropriate feature extraction, defining normal behaviors, handling imbalanced
   distribution of normal and abnormal data, addressing the variations in abnormal behavior, sparse occurrence of 
   abnormal events, environmental variations, camera movements, etc.
   The main disadvantage of anomaly detection is that it can be intimidating or seem complex. It's a branch of artificial
   intelligence involving machine learning models, neural networks, and enough things to make your head spin.
'''
# Out:
# "Challenges in anomaly detection include appropriate feature extraction, defining normal behaviors, handling imbalanced\n   distribution of normal and abnormal data, addressing the variations in abnormal behavior, sparse occurrence of \n   abnormal events, environmental variations, camera movements, etc.\n   The main disadvantage of anomaly detection is that it can be intimidating or seem complex. It's a branch of artificial\n   intelligence involving machine learning models, neural networks, and enough things to make your head spin.\n"

# %%
# Q3
'''Unsupervised learning algorithms are trained using unlabeled data. Supervised learning model takes direct feedback to
   check if it is predicting correct output or not. Unsupervised learning model does not take any feedback.
   We can think of unsupervised learning problems as being divided into two categories:
   1. clustering and 
   2. association rules.
'''
# Out:
# 'Unsupervised learning algorithms are trained using unlabeled data. Supervised learning model takes direct feedback to\n   check if it is predicting correct output or not. Unsupervised learning model does not take any feedback.\n   We can think of unsupervised learning problems as being divided into two categories:\n   1. clustering and \n   2. association rules.\n'

# %%
# Q4
'''There are three main classes of anomaly detection techniques:
1. unsupervised,
2. semi-supervised, and
3. supervised.
'''
# Out:
# 'There are three main classes of anomaly detection techniques:\n1. unsupervised,\n2. semi-supervised, and\n3. supervised.\n'

# %%
# Q5
'''The basic assumptions for anomaly detection are that the anomalies, or outliers, occur rarely in the data, and they 
   are significantly different from the expected pattern in the context being considered.
   Depending on the type of data gathering anomalies, one might take into account the three anomaly detection methods 
   and algorithms:
1. Unsupervised Clustering.
2. Supervised Classification. 
3. Semi-supervised Detection.
'''
# Out:
# 'The basic assumptions for anomaly detection are that the anomalies, or outliers, occur rarely in the data, and they \n   are significantly different from the expected pattern in the context being considered.\n   Depending on the type of data gathering anomalies, one might take into account the three anomaly detection methods and algorithms:\n1. Unsupervised Clustering.\n2. Supervised Classification. \n3. Semi-supervised Detection.\n'

# %%
# Q6
'''The Local Outlier Factor (LOF) algorithm is an unsupervised anomaly detection method which computes the local density 
   deviation of a given data point with respect to its neighbors. It considers as outliers the samples that have a 
   substantially lower density than their neighbors.
   The LOF of a point p is the sum of the LRD of all the points in the set kNearestSet(p) * the sum of the reachDistance 
   of all the points of the same set, to the point p , all divided by the number of items in the set, kNearestSetCount(p)
   , squared.
'''
# Out:
# 'The Local Outlier Factor (LOF) algorithm is an unsupervised anomaly detection method which computes the local density \n   deviation of a given data point with respect to its neighbors. It considers as outliers the samples that have a \n   substantially lower density than their neighbors.\n   The LOF of a point p is the sum of the LRD of all the points in the set kNearestSet(p) * the sum of the reachDistance \n   of all the points of the same set, to the point p , all divided by the number of items in the set, kNearestSetCount(p)\n   , squared.\n'

# %%
# Q7
'''Important parameters in Isolation Forest
1. number of trees / estimators : how big is the forest.
2. contamination: the fraction of the dataset that contains abnormal instances, e.g. 0.1 or 10%
3. max samples: The number of samples to draw from the training set to train each Isolation Tree with.
   Isolation Forest is an algorithm for data anomaly detection initially developed by Fei Tony Liu and Zhi-Hua Zhou in 
   2008. Isolation Forest detects anomalies using binary trees. The algorithm has a linear time complexity and a low 
   memory requirement, which works well with high-volume data.
'''
# Out:
# 'Important parameters in Isolation Forest\n1. number of trees / estimators : how big is the forest.\n2. contamination: the fraction of the dataset that contains abnormal instances, e.g. 0.1 or 10%\n3. max samples: The number of samples to draw from the training set to train each Isolation Tree with.\n   Isolation Forest is an algorithm for data anomaly detection initially developed by Fei Tony Liu and Zhi-Hua Zhou in \n   2008. Isolation Forest detects anomalies using binary trees. The algorithm has a linear time complexity and a low \n   memory requirement, which works well with high-volume data.\n'

# %%
# Q8
'''The k-nearest neighbor classifier fundamentally relies on a distance metric. The better that metric reflects label 
   similarity, the better the classified will be.
    The most common choice is the Minkowski distance 
                    dist(x,z)=(d∑r=1|xr−zr|p)1/p.
'''
# Out:
# 'The k-nearest neighbor classifier fundamentally relies on a distance metric. The better that metric reflects label \n   similarity, the better the classified will be.\n    The most common choice is the Minkowski distance \n                    dist(x,z)=(d∑r=1|xr−zr|p)1/p.\n'

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X, y = make_moons(n_samples=1000, noise=0.2)

# %%
plt.scatter(X[:,0],X[:,1])

# %%
from sklearn.cluster import DBSCAN

# %%
dbcan=DBSCAN(eps=0.1)

# %%
plt.scatter(X[:,0],X[:,1],c=dbcan.labels_)

# %%
plt.scatter(X[:,0],X[:,1],c=y)
